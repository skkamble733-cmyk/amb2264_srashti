# %%
ph=float(input("enter ph value"))
if(ph<5.5):
  print("acidic soil")
elif(ph<=7.5):
   print("neutral soil")
elif(ph<=8.5):
   print("alkaline soil")
else:
   print("highly alkline soil")
# Out:
# enter ph value4
# acidic soil

# %%
a=float(input("enter ph values"))
if(a<5.5):
 print("acidic soil")
elif(a=<7.5):
  print("neutral soil")
elif(a=<8.5):
   print("alkaline soil")
else:
  print("highly alkaline soil")
# Out:
#   File "/tmp/ipython-input-1322015767.py", line 4
#     elif(a=<7.5):
#           ^
# SyntaxError: invalid syntax

# %%
x=[10,20,30]
print(25 in x)
print(10 in x)
print(25 not in x)
print(x)

# %%
x=[10,20,30]
print(x)
for i in x:
  print("value of",i,"afer adding 2 is",i+2)
  print("value of {},after adding 2 is {}".format(i,i+2))

# %%
x=[10,11,13,14]
if 12 not in x:
  print("mark absent for 12")
if 11  in x:
  print("mark present for 11")
print("end")
# Out:
# mark absent for 12
# mark present for 11
# end

# %%
crops=["rice","wheat","maize"]
print("crops grown in the field:")
for crop in crops:
    print(crop)
    crops.append("sugarcane")
    print(crops)
