# %%
lst=[1,2,3]
for x in lst:
  lst.append(x)
  if len(lst)>3:
     break
print(lst)
# Out:
# [1, 2, 3, 1]

# %%
lst=[1,2,3]
for x in lst:
   if len(lst)>4:
     break
     lst.append(x)
print(lst)
# Out:
# [1, 2, 3]

# %%
lst=[1,2,3]
for x in lst:
   if len(lst)>4:
    lst.append(x)
    break
print(lst)
# Out:
# [1, 2, 3]

# %%
i=1
while(i>4):
  if i==4:
    break
  print(i)
  i+=1

# %%
x=25
if x>10:
  if x>20:
    print('a')
  else:
    print('b')
else:
  print('c')
# Out:
# a

# %%
nums=[5,10,15]
for n in nums:
  n+=5
print(nums)
n+=1
# Out:
# [5, 10, 15]
