# %%
for i in range(1,11):
  if i ==6:
   continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10

# %%
i=1
while(i<=10):
 if i==6:
   i+=1
   continue
 print(i)
 i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 10

# %%
for i in range (1,11):
  if i==6 or i==4:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 5
# 7
# 8
# 9
# 10

# %%
i=1
while(i<=10):
  if i==6 or i==4:
    i+=1
    continue
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 5
# 7
# 8
# 9
# 10

# %%
num=1
while num !=0:
  num= int(input("enter a number:"))
print(num)
# Out:
# enter a number:0
# 0

# %%
password=""
while password != "python":
   password =input("enter a password:")
print ("access granted")
# Out:
# enter a password:python
# access granted

# %%
i=1
sum=0
while (i<=10):
  sum=sum+i
  i=i+1
print(sum)
# Out:
# 55

# %%
sum = 0
for i in range(1, 6):
  sum = sum + i
print(sum)
# Out:
# 15

# %%
for(i=1;i<=5;i=i+1):
      sum=sum+i
print(sum)
# Out:
#   File "/tmp/ipython-input-1171872320.py", line 1
#     for(i=1;i<=5;i=i+1):
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
i=1
sum=0
while((sum+i)<=50):
  sum=sum+i
  i=i+1
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
a={1,2,3,4}
b={7,8,1,2}
a.update(b)
print(a)
# Out:
# {1, 2, 3, 4, 7, 8}

# %%
s={2,4,7,9}
s.pop()
print(s)
# Out:
# {2, 4, 7}

# %%
s={2,4,6,8}
s.remove(2)
print(s)
# Out:
# {8, 4, 6}

# %%
r={9,8,7,6,5,4}
r.discard(9)
print(r)
# Out:
# {4, 5, 6, 7, 8}

# %%
q={1,2,3}
q.clear()
print(q)
# Out:
# set()

# %%
a={'a','b'}
a.clear()
print(a)
# Out:
# set()

# %%
a={'a','b'}
a.del()
print(a)
# Out:
#   File "/tmp/ipython-input-904026020.py", line 2
#     a.del()
#       ^
# SyntaxError: invalid syntax

# %%
a={'a','b'}
a.add('c')
print(a)
# Out:
# {'c', 'b', 'a'}

# %%
a={1,2,3,4,54}
print(max(a))
# Out:
# 54

# %%
x={9,8,3,46,12}
print(min(x))
# Out:
# 3

# %%
a={23,5,7,9}
x=max(a)
print(x)
# Out:
# 23

# %%
c={5,4,3,2,1,6,7}
print(len(c))
# Out:
# 7

# %%
a={2,3,4,5,6,}
average=float (sum(a)/len(a))
print(average)
# Out:
# 4.0

# %%
a={1,2,3,45,1}
s=sum(a)
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2796171883.py in <cell line: 0>()
#       1 a={1,2,3,45,1}
# ----> 2 s=sum(a)
#       3 print(s)
#
# TypeError: 'int' object is not callable

# %%
s={1,2,3,4,5}
a = sum(s)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3635489149.py in <cell line: 0>()
#       1 s={1,2,3,4,5}
# ----> 2 a = sum(s)
#       3 print(a)
#
# TypeError: 'int' object is not callable

# %%
s={1,2,3,4}
a=sum(s)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2233520604.py in <cell line: 0>()
#       1 s={1,2,3,4}
# ----> 2 a=sum(s)
#       3 print(a)
#
# TypeError: 'int' object is not callable
