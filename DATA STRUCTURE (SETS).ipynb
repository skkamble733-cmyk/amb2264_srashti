# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(cgpa)
print(len(cgpa))
print(type(cgpa))
# Out:
# {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# 5
# <class 'dict'>

# %%
names={5:"latha",4:"srashti",3:"shree"}
print(names[5])
print(names[3])
print(names[4])
# Out:
# latha
# shree
# srashti

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
for k in cgpa:
 print("cgpa of",k,"-->",cgpa[k])

 print("cgpa of",k,"--\n>",cgpa[k])

 print("cgpa of",k,"--\\>",cgpa[k])

 print("cgpa of",k,"-->\t",cgpa[k])

 print("cgpa of",k,"-->\\n",cgpa[k])
# Out:
# cgpa of 1 --> 8.9
# cgpa of 1 --
# > 8.9
# cgpa of 1 --\> 8.9
# cgpa of 1 -->	 8.9
# cgpa of 1 -->\n 8.9
# cgpa of 2 --> 5.6
# cgpa of 2 --
# > 5.6
# cgpa of 2 --\> 5.6
# cgpa of 2 -->	 5.6
# cgpa of 2 -->\n 5.6
# cgpa of 4 --> 6.7
# cgpa of 4 --
# > 6.7
# cgpa of 4 --\> 6.7
# cgpa of 4 -->	 6.7
# cgpa of 4 -->\n 6.7
# cgpa of 7 --> 9.1
# cgpa of 7 --
# > 9.1
# cgpa of 7 --\> 9.1
# cgpa of 7 -->	 9.1
# cgpa of 7 -->\n 9.1
# cgpa of 8 --> 5.3
# cgpa of 8 --
# > 5.3
# cgpa of 8 --\> 5.3
# cgpa of 8 -->	 5.3
# cgpa of 8 -->\n 5.3

# %%
cgpa[3]=8.6
print("after adding(3)",cgpa)
# Out:
# after adding(3) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6}

# %%
cgpa[7]=9.3
print(" after updating(7)",cgpa)
# Out:
#  after updating(7) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.3, 8: 5.3, 3: 8.6, 9: 9.3}

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictionary ",cgpa)
# Out:
# dictionary  {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}

# %%
print("keys-->", cgpa.keys())
# Out:
# keys--> dict_keys([1, 2, 4, 7, 8])

# %%
print("values-->",cgpa.values())
# Out:
# values--> dict_values([8.9, 5.6, 6.7, 9.1, 5.3])

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("values-->",cgpa.values())
# Out:
# values--> dict_values([8.9, 5.6, 6.7, 9.1, 5.3])

# %%
cgpa.clear()
print("dictinory after clearing",cgpa)
print(type(cgpa))
# Out:
# dictinory after clearing {}
# <class 'dict'>

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
s=0
for i in cgpa:
  s=s+cgpa[i]
print("sum",s)
print("average",s/len(cgpa))
print("average",s//len(cgpa))
# Out:
# sum 35.599999999999994
# average 7.119999999999999
# average 7.0

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictinary",cgpa)
print("sum",sum(cgpa.values()))
print("average",sum(cgpa.values())/len(cgpa))
print("average",sum(cgpa.values())//len(cgpa))
# Out:
# dictinary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# sum 35.6
# average 7.12
# average 7.0

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(min(cgpa.values()))
# Out:
# 5.3

# %%
print(max(cgpa.values()))
# Out:
# 9.1

# %%
set={1,2,3,4,5}
print(type(set))
# Out:
# <class 'set'>

# %%
set.clear()
print(set)
# Out:
# set()
