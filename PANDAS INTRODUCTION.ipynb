# %%
import pandas as pd
production=pd.Series([30,60,45,25],
                     index=['wheat','rice','maize','barly']
                     )
print(production)
# Out:
# wheat    30
# rice     60
# maize    45
# barly    25
# dtype: int64

# %%
print(production['rice'])
print(production.loc['rice'])
# Out:
# 60
# 60

# %%
print(production.iloc[0])
# Out:
# 30

# %%
print(production.sum())
print(production.mean())
print(production.max())
print(production.idxmax(),'is having maximum value of',production.max())
# Out:
# 160
# 40.0
# 60
# rice is having maximum value of 60

# %%
increased_production=production*1.1
print(increased_production)
# Out:
# wheat    33.0
# rice     66.0
# maize    49.5
# barly    27.5
# dtype: float64

# %%
high_production=production[production>40]
print(high_production)
print()
print(production>40)
# Out:
# rice     60
# maize    45
# dtype: int64
#
# wheat    False
# rice      True
# maize     True
# barly    False
# dtype: bool

# %%
import pandas as pd
df=pd.DataFrame({
    'name':['akhil','robby','charran'],
    'age':[25,30,35],
    'city':['ny','la','chicago'],
},index=['a','b','c'])
print(df)
print()
print(df.loc['b'])
# Out:
#       name  age     city
# a    akhil   25       ny
# b    robby   30       la
# c  charran   35  chicago
#
# name    robby
# age        30
# city       la
# Name: b, dtype: object

# %%
print(df)
print()
print(df.loc[['a','c'],['name','city']])
# Out:
#       name  age     city
# a    akhil   25       ny
# b    robby   30       la
# c  charran   35  chicago
#
#       name     city
# a    akhil       ny
# c  charran  chicago
