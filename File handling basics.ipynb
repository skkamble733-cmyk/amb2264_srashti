# %%
file=open("abc.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2749428419.py in <cell line: 0>()
# ----> 1 file=open("abc.txt","r")
#       2 content=file.read()
#       3 print(content)
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
file=open("s.txt","w")
file.write("hello srashti")
file.close()

# %%
file=open("s.txt","r")
print (file.read())
file.close()
# Out:
# hello srashti

# %%
file=open("s.txt","w")
file.write("how are you")
file.close()

# %%
file=open("s.txt","r")
print (file.read())
file.close()
# Out:
# how are youhow are youhow are youhow are youhow are youhow are you

# %%
file=open("s.txt","a")
file.write("how are you")
file.close()
file=open("s.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hello srashtihow are youhow are you

# %%
with open ("t.txt","r") as file:
    print(file.read())
# Out:
# new content

# %%
try:
  file=open("xyz.txt","r")
  print(file.read())
  file.close()
except:
  print("no such file")
# Out:
# no such file

# %%
try:
  a=10
  b=20
  c=a+d
  print(c)
except:
  print("some issues")
# Out:
# some issues

# %%
def expr(a,b):
  c=a/b
  print(c)
a=2
b=4
expr(a,b)
# Out:
# 0.5

# %%
def expr(a,b):
  c=a/b
  print(c)
a=2
b=0
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-596323624.py in <cell line: 0>()
#       4 a=2
#       5 b=0
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-596323624.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=a/b
#       3   print(c)
#       4 a=2
#       5 b=0
#
# ZeroDivisionError: division by zero

# %%
def expr(a,b):
  c=b/d
  print(c)
a=2
b=4
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3675028627.py in <cell line: 0>()
#       4 a=2
#       5 b=4
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-3675028627.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=b/d
#       3   print(c)
#       4 a=2
#       5 b=4
#
# NameError: name 'd' is not defined

# %%
def expr(a,b):
  try:
    c=a/f
  except ZeroDivisionError:
    print("divided by zero")
  except NameError:
    print("variable not declared")
  except:
    print("some error occured")
  else:
    print("executed without errors")
    print("value of c")
  finally:
    print("end of the program")
a=5
b=2
expr(a,b)
# Out:
# variable not declared
# end of the program
