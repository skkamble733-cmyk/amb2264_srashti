# %%
marks={1:2.2,3:4.6,9:9.1}
print(marks)
print(len(marks))
print(type(marks))
# Out:
# {1: 2.2, 3: 4.6, 9: 9.1}
# 3
# <class 'dict'>

# %%
print(marks[1])
# Out:
# 2.2

# %%
print(marks[9])
# Out:
# 9.1

# %%
sky={"a":1,"b":2,"c":6}
print(sky)
# Out:
# {'a': 1, 'b': 2, 'c': 6}

# %%
for k in marks:
  print ("marks of  ",k,"\n",marks[k])
# Out:
# marks of   1
#  2.2
# marks of   3
#  4.6
# marks of   9
#  9.1

# %%
print (marks.keys())
# Out:
# dict_keys([1, 3, 9])

# %%
print(marks.values())
# Out:
# dict_values([2.2, 4.6, 9.1])

# %%
marks[2]=10
print(marks)
# Out:
# {1: 2.2, 3: 4.6, 9: 9.1, 2: 10}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
CGPA[9]=7.6
print("after adding(9):","\n"   ,CGPA)
# Out:
# after adding(9):
#  {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 9: 7.6}

# %%
CGPA[9]=10
print("after updating(9):","\n",CGPA)
# Out:
# after updating(9):
#  {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 9: 10}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
del CGPA[1]
print("after deleting (1): ",CGPA)
# Out:
# after deleting (1):  {2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}

# %%
del CGPA
print(CGPA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1975229976.py in <cell line: 0>()
# ----> 1 del CGPA
#       2 print(CGPA)
#
# NameError: name 'CGPA' is not defined

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
CGPA.clear()
print(CGPA)
print (type (CGPA))
# Out:
# {}
# <class 'dict'>

# %%
s={1,2,3}
s.clear()
print(s)
# Out:
# set()

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
s=0
for i in CGPA :
  s=s+CGPA[i]
print("sum",s)
print("average",s/len(CGPA))
print("average",s//len(CGPA))
# Out:
# sum 35.599999999999994
# average 7.119999999999999
# average 7.0

# %%
print("sum",sum(CGPA.values()))
print("average",sum(CGPA.values())/len(CGPA))
print("average",sum(CGPA.values())//len(CGPA))
# Out:
# sum 35.6
# average 7.12
# average 7.0

# %%
print(min(CGPA.values()))
print(max(CGPA.values()))
# Out:
# 5.3
# 9.1
