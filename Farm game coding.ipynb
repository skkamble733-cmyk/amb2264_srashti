# %%
cropcropss=0
points=0
while("true"):
  print("welcome to farm game")
  print("plant a seed")
  print("water the plants")
  print("harvest the plants")
  print("quit")
  choice=input("enter your choice")
  if choice=="1":
     crops+=1
     print("you have planted a seed")
  elif choice=="2":
    if crops>=1:

      print("you have watered the plants")
    else:
      print("water is not required")
  elif choice=="3":
    if crops>=1:
      points=points+(crops*5)
      print("you have harvested the plants")
      crops=0
    else:
      print("harvest is not required")
  elif choice=="4":
   print("you have quit the game")
   print("total  points",points)
   break
  else:
    print("invalid choice")
# Out:
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice1
# you have planted a seed
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice2
# you have watered the plants
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice3
# you have harvested the plants
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice1
# you have planted a seed
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice2
# you have watered the plants
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice3
# you have harvested the plants
# welcome to farm game
# plant a seed
# water the plants
# harvest the plants
# quit
# enter your choice4
# you have quit the game
# total  points 10

# %%
fish_dict={"rohu":20,"catla":30,"sinchu":12}
