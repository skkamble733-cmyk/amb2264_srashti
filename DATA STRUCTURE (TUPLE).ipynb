# %%
t=(2,3,4,5,6,7,8,9,1)
print('t[2]..>',t[1])
# Out:
# t[2]..> 3

# %%
print('t[-2]..>',t[-2])
# Out:
# t[-2]..> 9

# %%
print('t[::-1]..>',t[::-1])
# Out:
# t[::-1]..> (1, 9, 8, 7, 6, 5, 4, 3, 2)

# %%
print('1:5',t[1:5])
# Out:
# 1:5 (3, 4, 5, 6)

# %%
print(t[-6:-3])
# Out:
# (5, 6, 7)

# %%
t=("pratham",'sharma',3.14,3)
t.append(9,8)
print(t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-395027950.py in <cell line: 0>()
#       1 t=("pratham",'sharma',3.14,3)
# ----> 2 t.append(9,8)
#       3 print(t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t=("pratham",'sharma',3.14,3)
t.insert(2,'rahul')
print(t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2524333866.py in <cell line: 0>()
#       1 t=("pratham",'sharma',3.14,3)
# ----> 2 t.insert(2,'rahul')
#       3 print(t)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t=("pratham",'sharma',3.14,3)
print(t)
t1=list(t)
t1.append(9.8)
t=tuple(t1)
print('')
print('after add..>',t)
# Out:
# ('pratham', 'sharma', 3.14, 3)
#
# after add..> ('pratham', 'sharma', 3.14, 3, 9.8)

# %%
t=("pratham",'sharma',3.14,3)
print(t)
t1=list(t)
t1.insert(2,'rahul')
t=tuple(t1)
print('')
print('after add..>',t)
# Out:
# ('pratham', 'sharma', 3.14, 3)
#
# after add..> ('pratham', 'sharma', 'rahul', 3.14, 3)

# %%
t=("pratham",'sharma',3.14,3)
print(t)
print(type(t))
t1=list(t)
print(type(t1))
del t1[1]
t=tuple(t1)
print('')
print('after deleting..>',t)
# Out:
# ('pratham', 'sharma', 3.14, 3)
# <class 'tuple'>
# <class 'list'>
#
# after deleting..> ('pratham', 3.14, 3)

# %%
t1=(3, 4, 5, 6)
t2=(5, 6, 7)
t3=t1+t2
print(t3)
# Out:
# (3, 4, 5, 6, 5, 6, 7)

# %%
t1=(3, 4, 5, 6)
t2=(5, 6, 7)
t3=t1[:3]+t2[:2]
print(t3)
# Out:
# (3, 4, 5, 5, 6)

# %%
t=(3, 4, 5, 6, 5, 6, 7)
print(t.index(5))
# Out:
# 2

# %%
print(t.count(5))
# Out:
# 2

# %%
l1=[1,2,3]
print(id(l1))
l1.append(4)
print(id(l1))
# Out:
# 134812686675072
# 134812686675072

# %%
s={1,2,3}
print(id(s))
s.add(4)
print(id(s))
# Out:
# 134812672204512
# 134812672204512

# %%
d={'a':1,'b':2}
print(id(d))
d['c']=3
print(id(d))
# Out:
# 134812672481856
# 134812672481856

# %%
t=(1,2,3)
print(id(t))
t1=list(t)
t1.append(4)
t=tuple(t1)
print(id(t))
# Out:
# 134812686561536
# 134812672656384

# %%
s='python'
print(id(s))
s=s+'3'
print(id(s))
print(s)
s='python'
s[0]='j'
print(s)
# Out:
# 134813657627552
# 134813229781024
# python3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2183671201.py in <cell line: 0>()
#       5 print(s)
#       6 s='python'
# ----> 7 s[0]='j'
#       8 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))
x=x+20

print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11655304
# 11654664
